# %%
import keras
from keras.models import Model
from keras.preprocessing import image
from keras.applications.imagenet_utils import preprocess_input
from keras.layers import Input
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\Eliza Marie\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\ELIZAM~1\AppData\Local\Temp/ipykernel_8076/2025178467.py", line 1, in <cell line: 1>
#     import keras
#   File "C:\Users\Eliza Marie\anaconda3\lib\site-packages\keras\__init__.py", line 20, in <module>
#     from keras import distribute
#   File "C:\Users\Eliza Marie\anaconda3\lib\site-packages\keras\distribute\__init__.py", line 18, in <module>
#     from keras.distribute import sidecar_evaluator
#   File "C:\Users\Eliza Marie\anaconda3\lib\site-packages\keras\distribute\sidecar_evaluator.py", line 17, in <module>
#     import tensorflow.compat.v2 as tf
# ...

# %%
# Load the pre-trained AlexNet model
model = keras.applications.AlexNet(weights='imagenet', include_top=True)

# Create a Keras Model that outputs the activation values of the first convolutional layer
layer_outputs = [layer.output for layer in model.layers[:8]]
activation_model = Model(inputs=model.input, outputs=layer_outputs)

# Load an example image
img_path = 'example_image.jpg'
img = image.load_img(img_path, target_size=(227, 227))

# Preprocess the image
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# Use the activation model to get the feature maps for the first convolutional layer
activations = activation_model.predict(x)

# Display the feature maps
import matplotlib.pyplot as plt
plt.matshow(activations[0][0, :, :, 4], cmap='viridis')
